# %% [markdown]
# # Lab 6 - Clustering
# ## Coder Name: Janojit Chakraborty
# ## Coder Registration Number: 21112011

# %% [markdown]
# ### Description About The Dataset:<br>
#
#     1. Title: Car Evaluation Database
#
#     2. Sources:
#        (a) Creator: Marko Bohanec
#        (b) Donors: Marko Bohanec   (marko.bohanec@ijs.si)
#                    Blaz Zupan      (blaz.zupan@ijs.si)
#        (c) Date: June, 1997
#
#     3. Past Usage:
#
#        The hierarchical decision model, from which this dataset is
#        derived, was first presented in
#
#        M. Bohanec and V. Rajkovic: Knowledge acquisition and explanation for
#        multi-attribute decision making. In 8th Intl Workshop on Expert
#        Systems and their Applications, Avignon, France. pages 59-78, 1988.
#
#        Within machine-learning, this dataset was used for the evaluation
#        of HINT (Hierarchy INduction Tool), which was proved to be able to
#        completely reconstruct the original hierarchical model. This,
#        together with a comparison with C4.5, is presented in
#
#        B. Zupan, M. Bohanec, I. Bratko, J. Demsar: Machine learning by
#        function decomposition. ICML-97, Nashville, TN. 1997 (to appear)
#
#     4. Relevant Information Paragraph:
#
#        Car Evaluation Database was derived from a simple hierarchical
#        decision model originally developed for the demonstration of DEX
#        (M. Bohanec, V. Rajkovic: Expert system for decision
#        making. Sistemica 1(1), pp. 145-157, 1990.). The model evaluates
#        cars according to the following concept structure:
#
#        CAR                      car acceptability
#        . PRICE                  overall price
#        . . buying               buying price
#        . . maint                price of the maintenance
#        . TECH                   technical characteristics
#        . . COMFORT              comfort
#        . . . doors              number of doors
#        . . . persons            capacity in terms of persons to carry
#        . . . lug_boot           the size of luggage boot
#        . . safety               estimated safety of the car
#
#        Input attributes are printed in lowercase. Besides the target
#        concept (CAR), the model includes three intermediate concepts:
#        PRICE, TECH, COMFORT. Every concept is in the original model
#        related to its lower level descendants by a set of examples (for
#        these examples sets see http://www-ai.ijs.si/BlazZupan/car.html).
#
#        The Car Evaluation Database contains examples with the structural
#        information removed, i.e., directly relates CAR to the six input
#        attributes: buying, maint, doors, persons, lug_boot, safety.
#
#        Because of known underlying concept structure, this database may be
#        particularly useful for testing constructive induction and
#        structure discovery methods.
#
#     5. Number of Instances: 1728
#        (instances completely cover the attribute space)
#
#     6. Number of Attributes: 6
#
#     7. Attribute Values:
#
#        buying       v-high, high, med, low
#        maint        v-high, high, med, low
#        doors        2, 3, 4, 5-more
#        persons      2, 4, more
#        lug_boot     small, med, big
#        safety       low, med, high
#
#     8. Missing Attribute Values: none
#
#     9. Class Distribution (number of instances per class)
#
# | Class | N | N[%] |
# | --- | --- | --- |
# | unacc | 1210 | (70.023 %) |
# | acc | 384 | (22.222 %) |
# | good | 69 | (3.993 %) |
# | v-good | 65 | (3.762 %) |

# %% [markdown]
# ### Objective:
# - Explore Basic Clustering
# - Explore K-Means Clustering
# - Explore Hierarchical Clustering
# - Explore Agglomerative Clustering

# %% [markdown]
# ### Problem Definition:
#
# "In machine learning too, we often group examples as a first step to understand a subject (data set) in a machine learning system. Grouping unlabeled examples is called clustering. After clustering, each cluster is assigned a number called a cluster ID. Now, you can condense the entire feature set for an example into its cluster ID. Representing a complex example by a simple cluster ID makes clustering powerful. Extending the idea, clustering data can simplify large datasets. Machine learning systems can then use cluster IDs to simplify the processing of large datasets. Thus, clustering’s output serves as feature data for downstream ML systems." - Google Devs Course - Clustering.
#
#     1) Download the "Car Evaluation" Dataset from UCI Repository (https://archive.ics.uci.edu/ml/datasets/Car+Evaluation). Remove the target 'Class Values' from the dataset while applying clustering algorithms.
#     2) Find the optimal number of clusters using Elbow and Silhouette Method.
#     3) Compare KMeans and Agglomerative Clustering methods for clustering the instances in the above dataset.
#         Validate the optimal number of clusters found out in the previous question.
#         *Hint - Even if the algorithm does not require labels, for cross-checking of clustering values, you may use the labels.
#     4) Find what hyperparameters were suitable in KMeans (n_clusters, max_iter, init, algorithm)
#     5) Find what hyperparameters were suitable in Agglomerative Clustering (n_clusters, metric, linkage)
#     6) Plot Hierarchical Clustering (Dendrogram) [Source]
#     7) Compare the better clustering algorithm with any classification algorithm, and write your notes on the same.
#
#     Additional Exploration: Implement KMeans using TensorFlow Library / Try to make plots similar to example 1, example 2)

# %% [markdown]
# ### Approach/Methods:
# - Importing the Dataset
# - Perform Data Cleaning and Data Preprocessing
# - Perform Elbow and Silhouette Method
# - Perform KMeans And Agglomerative Clustering

# %% [markdown]
# ### Observation:
# - As Per Elbow Method Optimal Number of Clusters can be 2,3,4,5
# - After applying Silhouette Method we are able to find the correct Number of Clusters i.e. 2,4.
# - K - Mean Clustering has better Silhouette Score than Agglomerative Clustering.
#         KMeans silhouette score: 0.13141732814972126 , When no. Cluster: 2
#         KMeans silhouette score: 0.12121767734931627 , When no. Cluster: 3
#         KMeans silhouette score: 0.12226330776819237 , When no. Cluster: 4
#         KMeans silhouette score: 0.1197372423249286 , When no. Cluster: 5
#         KMeans silhouette score: 0.12358615144857359 , When no. Cluster: 6
#
#         Agglomerative clustering silhouette score: 0.11010609136752035 , When no. Cluster: 2
#         Agglomerative clustering silhouette score: 0.06959590793714607 , When no. Cluster: 3
#         Agglomerative clustering silhouette score: 0.06337186321260964 , When no. Cluster: 4
#         Agglomerative clustering silhouette score: 0.0657779465398541 , When no. Cluster: 5
#         Agglomerative clustering silhouette score: 0.06238839063184197 , When no. Cluster: 6
# - As per the Slihouete Score also 2 and 4 can be the optimal number of clusters for K-Means Clustering
# - For K-Means Clustering,
#         Best hyperparameters: {'n_clusters': 2, 'max_iter': 100, 'init': 'k-means++', 'algorithm': 'auto'}
#         Best silhouette score: 0.13141732814972126
# - For Agglomerative Clustering,
#         Best hyperparameters: {'n_clusters': 2, 'metric': 'euclidean', 'method': 'ward'}
#         Best silhouette score: 0.11010609136752035
# - Comparision between Clustering algorithms and Classification algorithms,
#         Best silhouette score for K-Means: 0.13141732814972126
#         Best silhouette score for Agglomerative: 0.11010609136752035
#         Accuracy Of Random Forest using K-Means Labels:  0.9884393063583815
#         Accuracy Of Random Forest using Agglomerative Labels:  0.9710982658959537

# %% [markdown]
# ### Learnings & Reflection:
# - Get Knowledge about Basic Clustering
# - Get Knowledge about K-Means Clustering
# - Get Knowledge Hierarchical Clustering
# - Get Knowledge Agglomerative Clustering

# %% [markdown]
# Name: **Janojit Chakraborty** <br>
# Reg No: **21112011** <br>
# Class: **4 BSC DS** <br>
#
# ---------------
#
#
# | Assignment | Status |
# | --- | --- |
# | 1 | __Completed__ |
# | 2 | __Completed__ |
# | 3 | __Completed__ |
# | 4 | __Completed__ |
# | 5 | __Completed__ |
# | 6 | __Completed__ |
# | 7 | __Completed__ |

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler, normalize
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt

# %% [markdown]
# ### Question 1

# %%
df = pd.read_csv('car.data', header = None, names = ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety','class values'])

# %%
df
# Out:
#      buying  maint  doors persons lug_boot safety class values
# 0     vhigh  vhigh      2       2    small    low        unacc
# 1     vhigh  vhigh      2       2    small    med        unacc
# 2     vhigh  vhigh      2       2    small   high        unacc
# 3     vhigh  vhigh      2       2      med    low        unacc
# 4     vhigh  vhigh      2       2      med    med        unacc
# ...     ...    ...    ...     ...      ...    ...          ...
# 1723    low    low  5more    more      med    med         good
# 1724    low    low  5more    more      med   high        vgood
# 1725    low    low  5more    more      big    low        unacc
# 1726    low    low  5more    more      big    med         good
# 1727    low    low  5more    more      big   high        vgood
#
# [1728 rows x 7 columns]

# %%
df = df.drop(['class values'], axis=1)

# %%
df
# Out:
#      buying  maint  doors persons lug_boot safety
# 0     vhigh  vhigh      2       2    small    low
# 1     vhigh  vhigh      2       2    small    med
# 2     vhigh  vhigh      2       2    small   high
# 3     vhigh  vhigh      2       2      med    low
# 4     vhigh  vhigh      2       2      med    med
# ...     ...    ...    ...     ...      ...    ...
# 1723    low    low  5more    more      med    med
# 1724    low    low  5more    more      med   high
# 1725    low    low  5more    more      big    low
# 1726    low    low  5more    more      big    med
# 1727    low    low  5more    more      big   high
#
# [1728 rows x 6 columns]

# %% [markdown]
# #### Data Preprocessing

# %%
df.isnull().sum()
# Out:
# buying      0
# maint       0
# doors       0
# persons     0
# lug_boot    0
# safety      0
# dtype: int64

# %%
df['doors'].unique()
# Out:
# array(['2', '3', '4', '5more'], dtype=object)

# %%
df['persons'].unique()
# Out:
# array(['2', '4', 'more'], dtype=object)

# %%
def ordinal_encoding(values):
    unique_values = list(set(values))
    encoding = {}
    for i, value in enumerate(sorted(unique_values)):
        encoding[value] = i
    encoded_values = [encoding[value] for value in values]
    return encoded_values

# %%
for col in df.columns:
    df[col] = ordinal_encoding(df[col])

# %%
df.dtypes
# Out:
# buying      int64
# maint       int64
# doors       int64
# persons     int64
# lug_boot    int64
# safety      int64
# dtype: object

# %%
df
# Out:
#       buying  maint  doors  persons  lug_boot  safety
# 0          3      3      0        0         2       1
# 1          3      3      0        0         2       2
# 2          3      3      0        0         2       0
# 3          3      3      0        0         1       1
# 4          3      3      0        0         1       2
# ...      ...    ...    ...      ...       ...     ...
# 1723       1      1      3        2         1       2
# 1724       1      1      3        2         1       0
# 1725       1      1      3        2         0       1
# 1726       1      1      3        2         0       2
# 1727       1      1      3        2         0       0
#
# [1728 rows x 6 columns]

# %% [markdown]
# ### Question 2

# %%
sse = []
K = range(1, 7)
for k in K:
    kmeans = KMeans(n_clusters=k, init='k-means++')
    kmeans.fit(df)
    sse.append(kmeans.inertia_)

plt.plot(K, sse, 'bx-')
plt.xlabel('Number of clusters')
plt.ylabel('SSE')
plt.title('The Elbow Method')
plt.show()

# %%
sil = []
K = range(2, 7)
for k in K:
    kmeans = KMeans(n_clusters=k, init='k-means++')
    kmeans.fit(df)
    sil.append(silhouette_score(df, kmeans.labels_))

plt.plot(K, sil, 'bx-')
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette Score')
plt.title('The Silhouette Method')
plt.show()

# %% [markdown]
# **Observation:**<br>
# - As Per Elbow Method Optimal Number of Clusters can be 2,3,4
# - After applying Silhouette Method we are able to find the correct Number of Clusters i.e. 2,4.

# %% [markdown]
# ### Question 3

# %%
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df)

for i in range(2,7):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans_labels = kmeans.fit_predict(df_scaled)
    kmeans_silhouette = silhouette_score(df_scaled, kmeans_labels)
    print("KMeans silhouette score:", kmeans_silhouette,", When no. Cluster:", i)
    
print("-"*70)

for i in range(2,7):
    agg = AgglomerativeClustering(n_clusters=i)
    agg_labels = agg.fit_predict(df_scaled)
    agg_silhouette = silhouette_score(df_scaled, agg_labels)
    print("Agglomerative clustering silhouette score:", agg_silhouette,", When no. Cluster:", i)
# Out:
# KMeans silhouette score: 0.1314173281497217 , When no. Cluster: 2
# KMeans silhouette score: 0.12121767734931631 , When no. Cluster: 3
# KMeans silhouette score: 0.12226330776819233 , When no. Cluster: 4
# KMeans silhouette score: 0.12070478166003246 , When no. Cluster: 5
# KMeans silhouette score: 0.12143255746341529 , When no. Cluster: 6
# ----------------------------------------------------------------------
# Agglomerative clustering silhouette score: 0.10490863590757497 , When no. Cluster: 2
# Agglomerative clustering silhouette score: 0.0719041755654025 , When no. Cluster: 3
# Agglomerative clustering silhouette score: 0.065426549938537 , When no. Cluster: 4
# Agglomerative clustering silhouette score: 0.06371068005078448 , When no. Cluster: 5
# Agglomerative clustering silhouette score: 0.066948350522065 , When no. Cluster: 6

# %% [markdown]
# **Observation:**<br>
# - K - Mean Clustering has better Silhouette Score than Agglomerative Clustering.
# - As per the Slihouete Score also 2 and 4 can be the optimal number of clusters

# %% [markdown]
# ### Question 4

# %%
n_clusters_range = [2, 3, 4, 5, 6]
max_iter_range = [100, 300, 500]
init_range = ['k-means++', 'random']
algorithm_range = ['auto', 'full', 'elkan']

best_score_kmean = -1
for n_clusters in n_clusters_range:
    for max_iter in max_iter_range:
        for init in init_range:
            for algorithm in algorithm_range:
                kmeans = KMeans(n_clusters=n_clusters, max_iter=max_iter, init=init, algorithm=algorithm, random_state=42)
                kmeans_labels = kmeans.fit_predict(df_scaled)
                score = silhouette_score(df_scaled, kmeans_labels)
                param = {'n_clusters': n_clusters, 'max_iter': max_iter, 'init': init, 'algorithm': algorithm}
                print("Hyperparameter:",param,"Silhouette score: ",score)
                print("-"*70)
                if score > best_score_kmean:
                    best_score_kmean = score
                    best_params_kmean = {'n_clusters': n_clusters, 'max_iter': max_iter, 'init': init, 'algorithm': algorithm}
                    
print("Best hyperparameters:", best_params_kmean)
print("Best silhouette score:", best_score_kmean)
# Out:
# Hyperparameter: {'n_clusters': 2, 'max_iter': 100, 'init': 'k-means++', 'algorithm': 'auto'} Silhouette score:  0.1314173281497217
# ----------------------------------------------------------------------
# Hyperparameter: {'n_clusters': 2, 'max_iter': 100, 'init': 'k-means++', 'algorithm': 'full'} Silhouette score:  0.1314173281497217
# ----------------------------------------------------------------------
# Hyperparameter: {'n_clusters': 2, 'max_iter': 100, 'init': 'k-means++', 'algorithm': 'elkan'} Silhouette score:  0.1314173281497217
# ----------------------------------------------------------------------
# Hyperparameter: {'n_clusters': 2, 'max_iter': 100, 'init': 'random', 'algorithm': 'auto'} Silhouette score:  0.1314173281497217
# ----------------------------------------------------------------------
# Hyperparameter: {'n_clusters': 2, 'max_iter': 100, 'init': 'random', 'algorithm': 'full'} Silhouette score:  0.1314173281497217
# ...

# %% [markdown]
# ### Question 5

# %%
n_clusters_range = [2, 3, 4, 5, 6]
metric_range = ['euclidean', 'manhattan', 'cosine']
linkage_range = ['ward', 'complete', 'average']

best_score_agg = -1
for n_clusters in n_clusters_range:
    for metric in metric_range:
        for linkage in linkage_range:
            try:
                agg = AgglomerativeClustering(n_clusters=n_clusters, metric=metric, linkage=linkage)
                agg_labels = agg.fit_predict(df_scaled)
                score = silhouette_score(df_scaled, agg_labels)
                param = {'n_clusters': n_clusters, 'metric': metric, 'method': linkage}
                print("Hyperparameter:",param,"Silhouette score: ",score)
                print("-"*70)
                if score > best_score_agg:
                    best_score_agg = score
                    best_params_agg = {'n_clusters': n_clusters, 'metric': metric, 'method': linkage}
            except:
                print(f"Error for n_clusters={n_clusters}, metric={metric}, method={linkage}")
                print("-"*70)

print("Best hyperparameters:", best_params_agg)
print("Best silhouette score:", best_score_agg)
# Out:
# Hyperparameter: {'n_clusters': 2, 'metric': 'euclidean', 'method': 'ward'} Silhouette score:  0.10490863590757497
# ----------------------------------------------------------------------
# Hyperparameter: {'n_clusters': 2, 'metric': 'euclidean', 'method': 'complete'} Silhouette score:  0.057094308647346666
# ----------------------------------------------------------------------
# Hyperparameter: {'n_clusters': 2, 'metric': 'euclidean', 'method': 'average'} Silhouette score:  0.08730985997359703
# ----------------------------------------------------------------------
# Error for n_clusters=2, metric=manhattan, method=ward
# ----------------------------------------------------------------------
# Hyperparameter: {'n_clusters': 2, 'metric': 'manhattan', 'method': 'complete'} Silhouette score:  0.06475049086272235
# ----------------------------------------------------------------------
# ...

# %% [markdown]
# ### Question 6

# %%
df.dtypes
# Out:
# buying      int64
# maint       int64
# doors       int64
# persons     int64
# lug_boot    int64
# safety      int64
# dtype: object

# %%
for metric in metric_range:
    for linkage in linkage_range:
        try:
            Z = linkage(df, method='ward', metric='euclidean')

            plt.figure(figsize=(25, 25))
            plt.title('Hierarchical Clustering Dendrogram')
            plt.xlabel('Sample Index')
            plt.ylabel('Distance')
            dendrogram(Z, leaf_rotation=90., leaf_font_size=8.)
            display(plt.show())
        except:
            print(f"Error for n_clusters={n_clusters}, metric={metric}, method={linkage}")
# Out:
# Error for n_clusters=6, metric=euclidean, method=ward
# Error for n_clusters=6, metric=euclidean, method=complete
# Error for n_clusters=6, metric=euclidean, method=average
# Error for n_clusters=6, metric=manhattan, method=ward
# Error for n_clusters=6, metric=manhattan, method=complete
# Error for n_clusters=6, metric=manhattan, method=average
# Error for n_clusters=6, metric=cosine, method=ward
# Error for n_clusters=6, metric=cosine, method=complete
# Error for n_clusters=6, metric=cosine, method=average

# %% [markdown]
# ### Question 7

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

X_train1, X_test1, y_train1, y_test1 = train_test_split(df, kmeans_labels, test_size=0.2, random_state=42)

rfc1 = RandomForestClassifier(n_estimators=100, random_state=42)
rfc1.fit(X_train1, y_train1)

y_pred1 = rfc1.predict(X_test1)

accuracy1 = accuracy_score(y_test1, y_pred1)

X_train2, X_test2, y_train2, y_test2 = train_test_split(df, agg_labels, test_size=0.2, random_state=42)

rfc2 = RandomForestClassifier(n_estimators=100, random_state=42)
rfc2.fit(X_train2, y_train2)

y_pred2 = rfc2.predict(X_test2)

accuracy2 = accuracy_score(y_test2, y_pred2)

# %%
print("Best silhouette score for K-Means:", best_score_kmean)
print("Best silhouette score for Agglomerative:", best_score_agg)
print("Accuracy Of Random Forest using K-Means Labels: ",accuracy1)
print("Accuracy Of Random Forest using Agglomerative Labels: ",accuracy2)
# Out:
# Best silhouette score for K-Means: 0.1314173281497217
# Best silhouette score for Agglomerative: 0.10490863590757497
# Accuracy Of Random Forest using K-Means Labels:  0.9826589595375722
# Accuracy Of Random Forest using Agglomerative Labels:  0.9421965317919075
